# %%
import tensorflow as tf
import numpy as np

# %%
x=tf.range(-100,100,4)

# %%
y=x+10

# %%
print(x.shape)
print(y.shape)
# Out:
# (50,)
# (50,)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)

# %% [markdown]
# training:model learns from this data<br>
# validation_data:model get tuned from this<br>
# test set :model evaluate what it have learned<br>

# %%
len(x)
# Out:
# 50

# %%
x_train=x[:40]
y_train=y[:40]
x_test=x[40:]
y_test=y[40:]

print(len(x_train))
print(len(y_train))
print(len(x_test))
print(len(y_test))
# Out:
# 40
# 40
# 10
# 10

# %%
plt.scatter(x_train,y_train,color='r')
plt.scatter(x_test,y_test,color='b')

# %%
print(x_train.shape)
# Out:
# (40,)

# %%
x_train = np.array(x_train).reshape(-1, 1)
x_test=np.array(x_test).reshape(-1,1)

# %%
model=tf.keras.Sequential([
    tf.keras.layers.Dense(1),
    tf.keras.layers.Dense(1)
    
])

model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"])

 
#x_train = np.array(x_train).reshape(-1, 1)
model.fit(x_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 43.4771 - mae: 43.4771
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.8467 - mae: 33.8467
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 13.3324 - mae: 13.3324
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.2971 - mae: 13.2971
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.6972 - mae: 20.6972
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.2697 - mae: 17.2697
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.2589 - mae: 21.2589
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 31.4276 - mae: 31.4276
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.7905 - mae: 11.7905
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.9031 - mae: 12.9031
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.9490 - mae: 24.9490
# Epoch 12/100
# ...

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ Layer (type)             ┃ Output Shape      ┃   Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━┩
# │ dense_6 (Dense)          │ (None, 1)         │         2 │
# ├──────────────────────────┼───────────────────┼───────────┤
# │ dense_7 (Dense)          │ (None, 1)         │         2 │
# └──────────────────────────┴───────────────────┴───────────┘
#  Total params: 6 (28.00 B)
#  Trainable params: 4 (16.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %% [raw]
# model.build()

# %%
tf.random.set_seed(42)
model=tf.keras.Sequential([
    tf.keras.layers.Dense(1,input_shape=x_train.shape)
])
model.compile(loss=tf.keras.losses.mae,optimizer=tf.keras.optimizers.SGD(),metrics=["mae"])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ Layer (type)             ┃ Output Shape      ┃   Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━┩
# │ dense_9 (Dense)          │ (None, 40, 1)     │         2 │
# └──────────────────────────┴───────────────────┴───────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### another word for <b>dense</b> is <b>fully connected</b>

# %%
model.fit(x_train,y_train,verbose=1,epochs=100)
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 56.7196 - mae: 56.7196
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 44.3374 - mae: 44.3374
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 41.8453 - mae: 41.8453
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 41.4003 - mae: 41.4003
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 41.1608 - mae: 41.1608
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 41.0659 - mae: 41.0659
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 41.0455 - mae: 41.0455
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 41.0416 - mae: 41.0416
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 41.0401 - mae: 41.0401
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 41.0390 - mae: 41.0390
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 41.0382 - mae: 41.0382
# Epoch 12/100
# ...

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                      │ (None, 1)                   │               2 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │               2 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 6 (28.00 B)
#  Trainable params: 4 (16.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
from tensorflow.keras.utils import plot_model

# %%
plot_model(model)
# Out:
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import plot_model
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(32,)))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)
# Out:
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.
# C:\Users\ashik\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
